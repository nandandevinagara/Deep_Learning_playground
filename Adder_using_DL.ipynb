# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Define the deep neural network architecture
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(2, 64)  # Input layer to hidden layer
        self.fc2 = nn.Linear(64, 64)  # Hidden layer to hidden layer
        self.fc3 = nn.Linear(64, 3)  # Hidden layer to output layer

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Prepare the input-output data
inputs = torch.tensor([[1,1], [0.1, 0.2], [0.5, 0.5], [0.9, 0.8], [0.2, 0.8], [0.3, 0.4]], dtype=torch.float32)
outputs = torch.tensor([2, 0, 2, 2, 0, 0], dtype=torch.int64)

# Create a DataLoader to handle batching and shuffling
dataset = TensorDataset(inputs, outputs)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# Instantiate the neural network model
model = NeuralNetwork()

# Define the loss function
criterion = nn.CrossEntropyLoss()

# Define the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train the model
num_epochs = 100
# the first for loop is just normal one
for epoch in range(num_epochs):
    # the second for loop runs based on the total number of inputs in dataset and the batch size
    # the number of times it runs in (total size of data/batch size) + 1 (depends if the division was not a whole number)
    # if there are 8 inputs and batch size is 3, then for loop runs 3 times (3,3,2 inputs in each run)
    # only thing dataloader does is shuffling the data in each epoch
     for inputs_batch, outputs_batch in dataloader:
        # print("inputs", inputs_batch)
        optimizer.zero_grad()
        predictions = model(inputs_batch)
        loss = criterion(predictions, outputs_batch)
        loss.backward()
        optimizer.step()
    # see weights after each training
     for name, param in model.named_parameters():
         if 'weight' in name:
             print("epoch = ", epoch, " ", param[0][0])
             # print(f'Layer: {name}, Size: {param.size()}, Weights: {param}')
     # break
     print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# Save the trained model if needed
# torch.save(model.state_dict(), 'model.pth')
# Out:
# epoch =  0   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  0   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  0   tensor(0.0454, grad_fn=<SelectBackward0>)
# Epoch [1/100], Loss: 1.0266
# epoch =  1   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  1   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  1   tensor(0.0453, grad_fn=<SelectBackward0>)
# Epoch [2/100], Loss: 1.0293
# epoch =  2   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  2   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  2   tensor(0.0446, grad_fn=<SelectBackward0>)
# Epoch [3/100], Loss: 0.9319
# epoch =  3   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  3   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  3   tensor(0.0440, grad_fn=<SelectBackward0>)
# Epoch [4/100], Loss: 0.9259
# epoch =  4   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  4   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  4   tensor(0.0436, grad_fn=<SelectBackward0>)
# Epoch [5/100], Loss: 0.9161
# epoch =  5   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  5   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  5   tensor(0.0433, grad_fn=<SelectBackward0>)
# Epoch [6/100], Loss: 0.8181
# epoch =  6   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  6   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  6   tensor(0.0427, grad_fn=<SelectBackward0>)
# Epoch [7/100], Loss: 0.8770
# epoch =  7   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  7   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  7   tensor(0.0423, grad_fn=<SelectBackward0>)
# Epoch [8/100], Loss: 0.8817
# epoch =  8   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  8   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  8   tensor(0.0418, grad_fn=<SelectBackward0>)
# Epoch [9/100], Loss: 0.8301
# epoch =  9   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  9   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  9   tensor(0.0413, grad_fn=<SelectBackward0>)
# Epoch [10/100], Loss: 0.7434
# epoch =  10   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  10   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  10   tensor(0.0408, grad_fn=<SelectBackward0>)
# Epoch [11/100], Loss: 0.7990
# epoch =  11   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  11   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  11   tensor(0.0404, grad_fn=<SelectBackward0>)
# Epoch [12/100], Loss: 0.7073
# epoch =  12   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  12   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  12   tensor(0.0399, grad_fn=<SelectBackward0>)
# Epoch [13/100], Loss: 0.7460
# epoch =  13   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  13   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  13   tensor(0.0395, grad_fn=<SelectBackward0>)
# Epoch [14/100], Loss: 0.5395
# epoch =  14   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  14   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  14   tensor(0.0391, grad_fn=<SelectBackward0>)
# Epoch [15/100], Loss: 0.6415
# epoch =  15   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  15   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  15   tensor(0.0387, grad_fn=<SelectBackward0>)
# Epoch [16/100], Loss: 0.5732
# epoch =  16   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  16   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  16   tensor(0.0383, grad_fn=<SelectBackward0>)
# Epoch [17/100], Loss: 0.6400
# epoch =  17   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  17   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  17   tensor(0.0380, grad_fn=<SelectBackward0>)
# Epoch [18/100], Loss: 0.7598
# epoch =  18   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  18   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  18   tensor(0.0377, grad_fn=<SelectBackward0>)
# Epoch [19/100], Loss: 0.6089
# epoch =  19   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  19   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  19   tensor(0.0374, grad_fn=<SelectBackward0>)
# Epoch [20/100], Loss: 0.5385
# epoch =  20   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  20   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  20   tensor(0.0371, grad_fn=<SelectBackward0>)
# Epoch [21/100], Loss: 0.5570
# epoch =  21   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  21   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  21   tensor(0.0368, grad_fn=<SelectBackward0>)
# Epoch [22/100], Loss: 0.6397
# epoch =  22   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  22   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  22   tensor(0.0364, grad_fn=<SelectBackward0>)
# Epoch [23/100], Loss: 0.5626
# epoch =  23   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  23   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  23   tensor(0.0360, grad_fn=<SelectBackward0>)
# Epoch [24/100], Loss: 0.4765
# epoch =  24   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  24   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  24   tensor(0.0355, grad_fn=<SelectBackward0>)
# Epoch [25/100], Loss: 0.6611
# epoch =  25   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  25   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  25   tensor(0.0350, grad_fn=<SelectBackward0>)
# Epoch [26/100], Loss: 0.4863
# epoch =  26   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  26   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  26   tensor(0.0344, grad_fn=<SelectBackward0>)
# Epoch [27/100], Loss: 0.5341
# epoch =  27   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  27   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  27   tensor(0.0337, grad_fn=<SelectBackward0>)
# Epoch [28/100], Loss: 0.6475
# epoch =  28   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  28   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  28   tensor(0.0331, grad_fn=<SelectBackward0>)
# Epoch [29/100], Loss: 0.6353
# epoch =  29   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  29   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  29   tensor(0.0324, grad_fn=<SelectBackward0>)
# Epoch [30/100], Loss: 0.6054
# epoch =  30   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  30   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  30   tensor(0.0318, grad_fn=<SelectBackward0>)
# Epoch [31/100], Loss: 0.4710
# epoch =  31   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  31   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  31   tensor(0.0311, grad_fn=<SelectBackward0>)
# Epoch [32/100], Loss: 0.6152
# epoch =  32   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  32   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  32   tensor(0.0304, grad_fn=<SelectBackward0>)
# Epoch [33/100], Loss: 0.4360
# epoch =  33   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  33   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  33   tensor(0.0296, grad_fn=<SelectBackward0>)
# Epoch [34/100], Loss: 0.5081
# epoch =  34   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  34   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  34   tensor(0.0287, grad_fn=<SelectBackward0>)
# Epoch [35/100], Loss: 0.3496
# epoch =  35   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  35   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  35   tensor(0.0277, grad_fn=<SelectBackward0>)
# Epoch [36/100], Loss: 0.6335
# epoch =  36   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  36   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  36   tensor(0.0265, grad_fn=<SelectBackward0>)
# Epoch [37/100], Loss: 0.3872
# epoch =  37   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  37   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  37   tensor(0.0253, grad_fn=<SelectBackward0>)
# Epoch [38/100], Loss: 0.3511
# epoch =  38   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  38   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  38   tensor(0.0239, grad_fn=<SelectBackward0>)
# Epoch [39/100], Loss: 0.5864
# epoch =  39   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  39   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  39   tensor(0.0225, grad_fn=<SelectBackward0>)
# Epoch [40/100], Loss: 0.3568
# epoch =  40   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  40   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  40   tensor(0.0210, grad_fn=<SelectBackward0>)
# Epoch [41/100], Loss: 0.2411
# epoch =  41   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  41   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  41   tensor(0.0193, grad_fn=<SelectBackward0>)
# Epoch [42/100], Loss: 0.4756
# epoch =  42   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  42   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  42   tensor(0.0176, grad_fn=<SelectBackward0>)
# Epoch [43/100], Loss: 0.4433
# epoch =  43   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  43   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  43   tensor(0.0158, grad_fn=<SelectBackward0>)
# Epoch [44/100], Loss: 0.3843
# epoch =  44   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  44   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  44   tensor(0.0139, grad_fn=<SelectBackward0>)
# Epoch [45/100], Loss: 0.5284
# epoch =  45   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  45   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  45   tensor(0.0122, grad_fn=<SelectBackward0>)
# Epoch [46/100], Loss: 0.4463
# epoch =  46   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  46   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  46   tensor(0.0106, grad_fn=<SelectBackward0>)
# Epoch [47/100], Loss: 0.3440
# epoch =  47   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  47   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  47   tensor(0.0092, grad_fn=<SelectBackward0>)
# Epoch [48/100], Loss: 0.4260
# epoch =  48   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  48   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  48   tensor(0.0078, grad_fn=<SelectBackward0>)
# Epoch [49/100], Loss: 0.3454
# epoch =  49   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  49   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  49   tensor(0.0066, grad_fn=<SelectBackward0>)
# Epoch [50/100], Loss: 0.3133
# epoch =  50   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  50   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  50   tensor(0.0054, grad_fn=<SelectBackward0>)
# Epoch [51/100], Loss: 0.3984
# epoch =  51   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  51   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  51   tensor(0.0044, grad_fn=<SelectBackward0>)
# Epoch [52/100], Loss: 0.1716
# epoch =  52   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  52   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  52   tensor(0.0033, grad_fn=<SelectBackward0>)
# Epoch [53/100], Loss: 0.4901
# epoch =  53   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  53   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  53   tensor(0.0020, grad_fn=<SelectBackward0>)
# Epoch [54/100], Loss: 0.3869
# epoch =  54   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  54   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  54   tensor(0.0006, grad_fn=<SelectBackward0>)
# Epoch [55/100], Loss: 0.3927
# epoch =  55   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  55   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  55   tensor(-0.0010, grad_fn=<SelectBackward0>)
# Epoch [56/100], Loss: 0.3337
# epoch =  56   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  56   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  56   tensor(-0.0025, grad_fn=<SelectBackward0>)
# Epoch [57/100], Loss: 0.1318
# epoch =  57   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  57   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  57   tensor(-0.0040, grad_fn=<SelectBackward0>)
# Epoch [58/100], Loss: 0.3939
# epoch =  58   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  58   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  58   tensor(-0.0056, grad_fn=<SelectBackward0>)
# Epoch [59/100], Loss: 0.2731
# epoch =  59   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  59   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  59   tensor(-0.0071, grad_fn=<SelectBackward0>)
# Epoch [60/100], Loss: 0.4558
# epoch =  60   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  60   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  60   tensor(-0.0087, grad_fn=<SelectBackward0>)
# Epoch [61/100], Loss: 0.3370
# epoch =  61   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  61   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  61   tensor(-0.0103, grad_fn=<SelectBackward0>)
# Epoch [62/100], Loss: 0.1664
# epoch =  62   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  62   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  62   tensor(-0.0119, grad_fn=<SelectBackward0>)
# Epoch [63/100], Loss: 0.4282
# epoch =  63   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  63   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  63   tensor(-0.0134, grad_fn=<SelectBackward0>)
# Epoch [64/100], Loss: 0.3379
# epoch =  64   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  64   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  64   tensor(-0.0146, grad_fn=<SelectBackward0>)
# Epoch [65/100], Loss: 0.0483
# epoch =  65   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  65   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  65   tensor(-0.0159, grad_fn=<SelectBackward0>)
# Epoch [66/100], Loss: 0.2963
# epoch =  66   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  66   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  66   tensor(-0.0173, grad_fn=<SelectBackward0>)
# Epoch [67/100], Loss: 0.1466
# epoch =  67   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  67   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  67   tensor(-0.0186, grad_fn=<SelectBackward0>)
# Epoch [68/100], Loss: 0.2473
# epoch =  68   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  68   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  68   tensor(-0.0198, grad_fn=<SelectBackward0>)
# Epoch [69/100], Loss: 0.3432
# epoch =  69   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  69   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  69   tensor(-0.0211, grad_fn=<SelectBackward0>)
# Epoch [70/100], Loss: 0.2288
# epoch =  70   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  70   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  70   tensor(-0.0222, grad_fn=<SelectBackward0>)
# Epoch [71/100], Loss: 0.0749
# epoch =  71   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  71   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  71   tensor(-0.0234, grad_fn=<SelectBackward0>)
# Epoch [72/100], Loss: 0.4318
# epoch =  72   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  72   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  72   tensor(-0.0247, grad_fn=<SelectBackward0>)
# Epoch [73/100], Loss: 0.3818
# epoch =  73   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  73   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  73   tensor(-0.0261, grad_fn=<SelectBackward0>)
# Epoch [74/100], Loss: 0.1585
# epoch =  74   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  74   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  74   tensor(-0.0274, grad_fn=<SelectBackward0>)
# Epoch [75/100], Loss: 0.1092
# epoch =  75   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  75   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  75   tensor(-0.0286, grad_fn=<SelectBackward0>)
# Epoch [76/100], Loss: 0.1533
# epoch =  76   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  76   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  76   tensor(-0.0298, grad_fn=<SelectBackward0>)
# Epoch [77/100], Loss: 0.1562
# epoch =  77   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  77   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  77   tensor(-0.0308, grad_fn=<SelectBackward0>)
# Epoch [78/100], Loss: 0.2229
# epoch =  78   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  78   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  78   tensor(-0.0318, grad_fn=<SelectBackward0>)
# Epoch [79/100], Loss: 0.0600
# epoch =  79   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  79   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  79   tensor(-0.0329, grad_fn=<SelectBackward0>)
# Epoch [80/100], Loss: 0.0494
# epoch =  80   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  80   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  80   tensor(-0.0340, grad_fn=<SelectBackward0>)
# Epoch [81/100], Loss: 0.0472
# epoch =  81   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  81   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  81   tensor(-0.0351, grad_fn=<SelectBackward0>)
# Epoch [82/100], Loss: 0.0452
# epoch =  82   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  82   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  82   tensor(-0.0363, grad_fn=<SelectBackward0>)
# Epoch [83/100], Loss: 0.0837
# epoch =  83   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  83   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  83   tensor(-0.0375, grad_fn=<SelectBackward0>)
# Epoch [84/100], Loss: 0.1252
# epoch =  84   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  84   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  84   tensor(-0.0387, grad_fn=<SelectBackward0>)
# Epoch [85/100], Loss: 0.1018
# epoch =  85   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  85   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  85   tensor(-0.0398, grad_fn=<SelectBackward0>)
# Epoch [86/100], Loss: 0.3406
# epoch =  86   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  86   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  86   tensor(-0.0412, grad_fn=<SelectBackward0>)
# Epoch [87/100], Loss: 0.1437
# epoch =  87   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  87   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  87   tensor(-0.0424, grad_fn=<SelectBackward0>)
# Epoch [88/100], Loss: 0.0369
# epoch =  88   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  88   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  88   tensor(-0.0436, grad_fn=<SelectBackward0>)
# Epoch [89/100], Loss: 0.3596
# epoch =  89   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  89   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  89   tensor(-0.0450, grad_fn=<SelectBackward0>)
# Epoch [90/100], Loss: 0.1248
# epoch =  90   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  90   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  90   tensor(-0.0463, grad_fn=<SelectBackward0>)
# Epoch [91/100], Loss: 0.2958
# epoch =  91   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  91   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  91   tensor(-0.0477, grad_fn=<SelectBackward0>)
# Epoch [92/100], Loss: 0.2475
# epoch =  92   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  92   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  92   tensor(-0.0492, grad_fn=<SelectBackward0>)
# Epoch [93/100], Loss: 0.0341
# epoch =  93   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  93   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  93   tensor(-0.0505, grad_fn=<SelectBackward0>)
# Epoch [94/100], Loss: 0.2650
# epoch =  94   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  94   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  94   tensor(-0.0519, grad_fn=<SelectBackward0>)
# Epoch [95/100], Loss: 0.2564
# epoch =  95   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  95   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  95   tensor(-0.0533, grad_fn=<SelectBackward0>)
# Epoch [96/100], Loss: 0.1735
# epoch =  96   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  96   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  96   tensor(-0.0547, grad_fn=<SelectBackward0>)
# Epoch [97/100], Loss: 0.0876
# epoch =  97   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  97   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  97   tensor(-0.0558, grad_fn=<SelectBackward0>)
# Epoch [98/100], Loss: 0.1556
# epoch =  98   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  98   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  98   tensor(-0.0570, grad_fn=<SelectBackward0>)
# Epoch [99/100], Loss: 0.0870
# epoch =  99   tensor(-0.2032, grad_fn=<SelectBackward0>)
# epoch =  99   tensor(0.1014, grad_fn=<SelectBackward0>)
# epoch =  99   tensor(-0.0580, grad_fn=<SelectBackward0>)
# Epoch [100/100], Loss: 0.1440

# %%
print(model)
# Out:
# NeuralNetwork(
#   (fc1): Linear(in_features=2, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=3, bias=True)
# )

# %%
for name, param in model.named_parameters():
    print(f"Parameter {name}, shape {param.shape}")
# Out:
# Parameter fc1.weight, shape torch.Size([64, 2])
# Parameter fc1.bias, shape torch.Size([64])
# Parameter fc2.weight, shape torch.Size([64, 64])
# Parameter fc2.bias, shape torch.Size([64])
# Parameter fc3.weight, shape torch.Size([3, 64])
# Parameter fc3.bias, shape torch.Size([3])

# %%
# Assuming the model is already trained and available

# Define new input data
new_inputs = torch.tensor([[0.6, 0.7], [0.2, 0.3], [0.8, 0.1]], dtype=torch.float32)

# Make predictions on new inputs
with torch.no_grad():
    predictions = model(new_inputs)

# Convert predictions to class labels
predicted_classes = torch.argmax(predictions, dim=1)

# Print predicted class labels
print("Predicted Classes:")
for i, pred_class in enumerate(predicted_classes):
    print(f"Input {i+1}: Predicted Class {pred_class.item()}")
# Out:
# Predicted Classes:
# Input 1: Predicted Class 2
# Input 2: Predicted Class 0
# Input 3: Predicted Class 2
